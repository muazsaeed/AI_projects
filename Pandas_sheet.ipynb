# %%
import pandas as pd

# %% [markdown]
# ## Data Structure in pandas
# #### DataFrame: is a two-dimensional, tabular data structure with labeled axes (rows and columns).
# #### Series: is a one-dimensional labeled array capable of holding any data type. It can be thought of as a single column of a DataFrame. A DataFrame is essentially a collection of Series.

# %%
#create dataframe
Data_frame=pd.DataFrame({'Name':['Ali','Hamza','Muaaz'],'Age':[20,21,22],'Gender':['Male','Male','Male'],'Smester':[6,6,6]})
print(Data_frame)
print(type(Data_frame))
# Out:
#     Name  Age Gender  Smester
# 0    Ali   20   Male        6
# 1  Hamza   21   Male        6
# 2  Muaaz   22   Male        6
# <class 'pandas.core.frame.DataFrame'>

# %%
ages = pd.Series([22, 35, 58], name="Age")
print(ages)
print(type(ages))
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
Data_frame=pd.read_csv('train.csv')
Data_frame.head(3) #show 1st 3 rows of data 
Data_frame.tail(3) #show last 3 rows of data
print(Data_frame.shape)
# Out:
# (891, 12)

# %%
Data_frame.describe()  # Describe function give statistics of all columns of type integer
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
Data_frame.dtypes #it just show data types of columns. When asking for the dtypes, no brackets are used! dtypes is an attribute of a DataFrame and Series. Attributes of a DataFrame or Series do not need brackets
Data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
Name=Data_frame['Name']
print(type(Name))
print(Data_frame['Name'].shape)
# Out:
# <class 'pandas.core.series.Series'>
# (891,)

# %%
Data_frame[['Name','Age']] #To select multiple columns, use a list of column names within the selection brackets [].
print(type(Data_frame[['Name','Age']]))
print(Data_frame[['Name','Age']].shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (891, 2)

# %% [markdown]
# ### When you want to apply operation on Dataset like SQL Queries

# %%
Data_frame[Data_frame['Age']>35] #its like SQL where clause
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Data_frame[Data_frame['Pclass'].isin([1,2])] #it show those row which have Pclass value 1 or 2, this is for catagorical data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Data_frame[Data_frame['Age'].notna()] #show rows where Data in Age is not null
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Data_frame.loc[Data_frame['Age']>35,'Name']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
# 13                           Andersson, Mr. Anders Johan
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 865                             Bystrom, Mrs. (Karolina)
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873                          Vander Cruyssen, Mr. Victor
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885                 Rice, Mrs. William (Margaret Norton)
# Name: Name, Length: 217, dtype: object

# %%
Data_frame[200:250] # show rows from 200 to 250
Data_frame.iloc[0,3] #show cell have row index 0 and column index 3
Data_frame.iloc[0:250,0:3] #show rows from index 0 to 250 and show clumn from index 0 to 3
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 245          246         0       1
# 246          247         0       3
# 247          248         1       2
# 248          249         1       1
# 249          250         0       2
#
# [250 rows x 3 columns]

# %%
Data_frame['New_Column']=Data_frame['Survived']+Data_frame['Pclass']
Data_frame.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_Column
# 0      0         A/5 21171   7.2500   NaN        S           3
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           4

# %%
Data_frame=Data_frame.rename(columns={"New_Column":"sum_column"}) #rename clumn name
Data_frame.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  sum_column
# 0      0         A/5 21171   7.2500   NaN        S           3
# 1      0          PC 17599  71.2833   C85        C           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S           4

# %% [markdown]
# ## Check Statistics

# %%
print(Data_frame['Age'].mean())#.median(),.max(),.min(),.count()
print(Data_frame[['Age','Fare']].mean()) #it return series
# Out:
# 29.69911764705882
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
(Data_frame[['Age','Sex','Fare']].groupby(['Sex'])).groups
# Out:
# {'female': [1, 2, 3, 8, 9, 10, 11, 14, 15, 18, 19, 22, 24, 25, 28, 31, 32, 38, 39, 40, 41, 43, 44, 47, 49, 52, 53, 56, 58, 61, 66, 68, 71, 79, 82, 84, 85, 88, 98, 100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140, 141, 142, 147, 151, 156, 161, 166, 167, 172, 177, 180, 184, 186, 190, 192, 194, 195, 198, 199, 205, 208, 211, 215, 216, 218, 229, 230, 233, 235, 237, 240, 241, 246, 247, 251, 254, 255, 256, 257, 258, 259, 264, 268, 269, 272, 274, 275, 276, ...], 'male': [0, 4, 5, 6, 7, 12, 13, 16, 17, 20, 21, 23, 26, 27, 29, 30, 33, 34, 35, 36, 37, 42, 45, 46, 48, 50, 51, 54, 55, 57, 59, 60, 62, 63, 64, 65, 67, 69, 70, 72, 73, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124, 125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, ...]}

# %%
Data_frame[['Sex','Age']].groupby('Sex').median() #output is Series
Data_frame[['Sex','Age','Fare']].groupby('Sex').median() #output is data_frame
# Out:
#          Age  Fare
# Sex
# female  27.0  23.0
# male    29.0  10.5

# %%
Data_frame.groupby('Sex').mean(numeric_only=True)
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare  sum_column
# Sex
# female  44.479818    2.901274
# male    25.523893    2.578856

# %%
Data_frame['Pclass'].value_counts() #it tell us number of elements in catagories
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
Data_frame.sort_values(by='Age') #it sort data set on Age column
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
# output_datframe=pd.concat([dataframe1,dataframe2],axis=0) to combine 2 or more frame

# %%
# output_datframe=pd.concat([dataframe1,dataframe2],hoe='Left',on='varaible_name') #like innerjoin

# %% [markdown]
# ## operation on textual data

# %%
Data_frame['Name'].str.lower()
Data_frame['Name'].str.split(',')
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
Data_frame["Sex"] = Data_frame["Sex"].replace({"male": "M", "female": "F})

# %%
cities = ['New York', 'San Francisco', 'Los Angeles'] #list
# Adding a new column 'City' to the DataFrame
df['City'] = cities

# %%
Data_frame['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
Data_frame['Age']=Data_frame['Age'].fillna(Data_frame['Age'].meadin())

# %%
Data_frame['Age'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
Data_frame.drop(['Name','ticket'],axis=1) #to remove column from dataframe

# %%
Data_frame.to_csv('output.csv',index=True) #if index=True it also store columns name and viceversa if index=False

# %%
# 1 method to add column in dataframe 
list1=['1',3,'5']
Data_frame['new_column']=list1
